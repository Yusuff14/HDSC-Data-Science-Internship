# %%
import pandas as pd
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
food_data = pd.read_csv(url, encoding='latin1')

# %%
#13 total number and percentage of missing data in 2016 to 2 decimal places

total_sum=food_data['Y2016'].sum()
null_sum=food_data['Y2016'].isnull().sum()
print(round(null_sum, 2))
print(round((null_sum/total_sum)*100, 2))
# Out:
# 1535
# 0.02

# %%
#12 Mean and standard deviation for the year 2015

print('mean =' ,round(food_data['Y2015'].mean(),3))
print('standard deviation =' ,round(food_data['Y2015'].std(),3))
# Out:
# mean = 135.236
# standard deviation = 1603.404

# %%
#11. Total sum of animal fat produced in 2014 and 2017

food_data.groupby('Item')[['Y2014','Y2017']].sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
#15 The year with the highest sum of import quantity

food_data.groupby('Element')[['Y2014','Y2015','Y2016','Y2017','Y2018']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
#16 Total number of the sum of production in 2014

food_data.groupby('Element')[['Y2014']].sum()
# Out:
#                                              Y2014
# Element
# Domestic supply quantity                1996716.35
# Export Quantity                          150020.64
# Fat supply quantity (g/capita/day)        10225.56
# Feed                                     216927.89
# Food                                    1212332.49
# Food supply (kcal/capita/day)            454257.00
# Food supply quantity (kg/capita/yr)       49650.63
# Import Quantity                          274144.48
# Losses                                   153223.00
# Other uses (non-food)                     78718.13
# Processing                               282923.00
# Production                              1931287.75
# Protein supply quantity (g/capita/day)    11836.46
# Residuals                                 30149.00
# Seed                                      21922.92
# Stock Variation                           58749.83
# Total Population - Both sexes           1031585.00
# ...

# %%
#17 The element having the highest sum in 2018

food_data.groupby('Element')[['Element','Y2018']].sum().sort_values(by='Y2018', ascending=False)
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Production                              2075072.89
# Food                                    1303841.28
# Total Population - Both sexes           1140605.00
# Food supply (kcal/capita/day)            455261.00
# Processing                               308429.00
# Import Quantity                          287997.09
# Feed                                     233489.68
# Export Quantity                          181594.80
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Food supply quantity (kg/capita/yr)       49056.85
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Protein supply quantity (g/capita/day)    11833.56
# Fat supply quantity (g/capita/day)        10258.69
# ...

# %%
#18 The element having the 3rd lowest sum in 2018

food_data.groupby('Element')[['Element','Y2018']].sum().sort_values(by=['Y2018'])
# Out:
#                                              Y2018
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Stock Variation                           20577.91
# Seed                                      25263.14
# Residuals                                 34864.00
# Food supply quantity (kg/capita/yr)       49056.85
# Other uses (non-food)                     91300.97
# Losses                                   163902.00
# Export Quantity                          181594.80
# Feed                                     233489.68
# Import Quantity                          287997.09
# Processing                               308429.00
# Food supply (kcal/capita/day)            455261.00
# Total Population - Both sexes           1140605.00
# Food                                    1303841.28
# Production                              2075072.89
# ...

# %%
#19 Total import quantity in algeria

food_data.groupby(['Area','Element']).sum().T
# Out:
# Area                          Algeria                  \
# Element      Domestic supply quantity Export Quantity
# Area Code                      464.00          392.00
# Item Code                   311204.00       264011.00
# Element Code                614916.00       579278.00
# Y2014                        83755.94         1328.64
# Y2015                        85972.86         1104.62
# Y2016                        87157.61         1340.22
# Y2017                        86810.42         1494.54
# Y2018                        90023.42          811.54
#
# Area                                                                   \
# Element      Fat supply quantity (g/capita/day)       Feed       Food
# Area Code                                432.00      88.00     420.00
# Item Code                             291489.00   58967.00  282744.00
# Element Code                           73872.00  121462.00  539910.00
# Y2014                                    320.19    9656.04   60582.69
# ...

# %%
#20 total number of unique countries in the dataset

food_data['Area'].describe(include='all')
# Out:
# count     60943
# unique       49
# top       Kenya
# freq       1560
# Name: Area, dtype: object

# %%
#14 the year with the highest correlation with ‘Element Code’

food_data.groupby(['Element Code'])[['Y2014','Y2015','Y2016','Y2017','Y2018']].corr()
# Out:
#                        Y2014     Y2015     Y2016     Y2017     Y2018
# Element Code
# 511          Y2014  1.000000  0.999988  0.999951  0.999885  0.999791
#              Y2015  0.999988  1.000000  0.999987  0.999947  0.999878
#              Y2016  0.999951  0.999987  1.000000  0.999986  0.999944
#              Y2017  0.999885  0.999947  0.999986  1.000000  0.999986
#              Y2018  0.999791  0.999878  0.999944  0.999986  1.000000
# ...                      ...       ...       ...       ...       ...
# 5911         Y2014  1.000000  0.976942  0.992694  0.941934  0.942024
#              Y2015  0.976942  1.000000  0.965195  0.863665  0.863140
#              Y2016  0.992694  0.965195  1.000000  0.963790  0.963378
#              Y2017  0.941934  0.863665  0.963790  1.000000  0.999409
#              Y2018  0.942024  0.863140  0.963378  0.999409  1.000000
#
# [90 rows x 5 columns]
